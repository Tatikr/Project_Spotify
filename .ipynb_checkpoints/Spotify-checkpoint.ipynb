# %% [markdown]
# 1 РАЗДЕЛ
# Обновление библиотек, загрузка данных, чистка данных, изучение данных

# %%
# Импорт библиотек

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from datetime import date,timedelta

# %%
#загрузка датафрейма
df = pd.read_csv('songs_normalize.csv')

# %%
#вывод таблицы для ознакомения с ней
df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# 0        False  2000          77         0.751   0.834    1    -5.444     0
# 1        False  1999          79         0.434   0.897    0    -4.918     1
# 2        False  1999          66         0.529   0.496    7    -9.007     1
# 3        False  2000          78         0.551   0.913    0    -4.063     0
# 4        False  2000          65         0.614   0.928    8    -4.806     0
# ...        ...   ...         ...           ...     ...  ...       ...   ...
# 1995     False  2019          79         0.842   0.734    1    -5.065     0
# 1996     False  2019          78         0.552   0.702    9    -5.707     1
# 1997     False  2019          69         0.847   0.678    9    -8.635     1
# 1998     False  2019          75         0.741   0.520    8    -7.513     1
# 1999     False  2019          85         0.695   0.762    0    -3.497     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0437        0.3000          0.000018    0.3550    0.894   95.053
# 1          0.0488        0.0103          0.000000    0.6120    0.684  148.726
# 2          0.0290        0.1730          0.000000    0.2510    0.278  136.859
# 3          0.0466        0.0263          0.000013    0.3470    0.544  119.992
# 4          0.0516        0.0408          0.001040    0.0845    0.879  172.656
# ...           ...           ...               ...       ...      ...      ...
# 1995       0.0588        0.0427          0.000000    0.1060    0.952  137.958
# 1996       0.1570        0.1170          0.000021    0.1050    0.564  169.994
# 1997       0.1090        0.0669          0.000000    0.2740    0.811   97.984
# 1998       0.0656        0.4500          0.000002    0.2220    0.347  102.998
# 1999       0.0395        0.1920          0.002440    0.0863    0.553  120.042
#
#                  genre
# 0                  pop
# 1            rock, pop
# 2         pop, country
# 3          rock, metal
# 4                  pop
# ...                ...
# 1995               pop
# 1996               pop
# 1997  hip hop, country
# 1998               pop
# 1999           hip hop
#
# [2000 rows x 18 columns]

# %% [markdown]
# *artist: Имя исполнителя.
# * song: (песня): Название трека.
# * duration_ms: Длительность трека в миллисекундах.
# * explicit: (явный, слишком откровенный): Текст или содержание песни или музыкального видео содержат один или несколько критериев, которые могут быть сочтены оскорбительными или неподходящими для детей.
# * year: Год выпуска трека.
# * popularity (популярность): Чем выше значение, тем популярнее песня.
# *  danceability (Танцевальность): Танцевальность описывает, насколько трек подходит для танцев на основе комбинации музыкальных элементов, включая темп, стабильность ритма, силу бита и общую регулярность. Значение 0,0 — наименее танцевальное, а 1,0 — наиболее танцевальное.
# * energy (энергия): Энергия является мерой от 0,0 до 1,0 и представляет собой перцептивную (процесс отражения событий) меру интенсивности и активности.
# * key: (ключ) Тональность, в которой находится трек.. Если ключ не обнаружен, значение равно -1.
# * loudness: (громкость) Общая громкость трека в децибелах (дБ). Значения громкости усредняются по всей дорожке и полезны для сравнения относительной громкости дорожек. Громкость – это качество звука, которое является первичным психологическим коррелятом физической силы (амплитуды). Значения обычно находятся в диапазоне от -60 до 0 дБ.
# * mode: (модальность) Mode указывает модальность (мажорную или минорную) трека, тип гаммы, из которой получено его мелодическое содержание. Мажор обозначается цифрой 1, а минор — 0.
# * Speechiness: (определяет наличие произнесенных слов в треке). Чем больше запись похожа исключительно на речь (например, ток-шоу, аудиокнига, поэзия), тем ближе к 1.0 значение атрибута. Значения выше 0,66 описывают треки, которые, вероятно, полностью состоят из произнесенных слов. Значения от 0,33 до 0,66 описывают треки, которые могут содержать как музыку, так и речь, как в разделах, так и в слоях, включая такие случаи, как рэп-музыка. Значения ниже 0,33, скорее всего, представляют музыку и другие треки, не похожие на речь.
# * acousticness (Акустическость) Достоверная мера от 0.0 до 1.0 того, является ли трек акустическим. 1.0 означает высокую уверенность в том, что трек является акустическим.
# * instrumentalness (инструментальность): предсказывает, содержит ли трек вокал. Звуки «ох» и «ааа» в этом контексте рассматриваются как инструментальные. Рэп или треки с устной речью явно «вокальные». Чем ближе значение инструментальности к 1.0, тем больше вероятность того, что трек не содержит вокального контента. Значения выше 0,5 предназначены для представления инструментальных треков, но достоверность тем выше, чем ближе значение к 1,0.
# * liveness: Определяет присутствие аудитории в записи. Более высокие значения живости означают повышенную вероятность того, что трек был исполнен в прямом эфире. Значение выше 0,8 обеспечивает высокую вероятность того, что трек находится в прямом эфире.
# * valence (валентность): Мера от 0,0 до 1,0, описывающая музыкальную позитивность, передаваемую треком. Треки с высокой валентностью звучат более позитивно (например, счастливый, веселый, эйфорический), в то время как треки с низкой валентностью звучат более негативно (например, грустный, подавленный, сердитый).
# эйфорический), в то время как треки с низкой валентностью звучат более негативно (например, грустный, подавленный, сердитый).
# * tempo: Общий расчетный темп трека в ударах в минуту (BPM). В музыкальной терминологии темп — это скорость или темп данного произведения, который напрямую зависит от средней длительности удара.
# * genre: Жанр трека.

# %%
#информация о датасете
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
#  16  tempo             2000 non-null   float64
#  17  genre             2000 non-null   object
# dtypes: bool(1), float64(9), int64(5), object(3)
# memory usage: 267.7+ KB
# None

# %%
#вывести количество строк и столбцов
df.shape
# Out:
# (2000, 18)

# %%
#типы данных 
df.dtypes
# Out:
# artist               object
# song                 object
# duration_ms           int64
# explicit               bool
# year                  int64
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# genre                object
# dtype: object

# %%
#Посмотреть, сколько записей для каждой из artist
df.artist.value_counts()
# Out:
# artist
# Rihanna           25
# Drake             23
# Eminem            21
# Calvin Harris     20
# Britney Spears    19
#                   ..
# Sidney Samson      1
# Cam’ron            1
# Elvis Presley      1
# Lucenzo            1
# Blanco Brown       1
# Name: count, Length: 835, dtype: int64

# %% [markdown]
# Самое большое количество песен у Рианны, посмотрим подробнее датасет по ее данным

# %%
#Создать датафрейм Rihanna с данными только где artist=’Rihanna’
Rihanna = df.query("artist == 'Rihanna'")

# %%
#просмотр нового датафрейма
Rihanna.head(5)
# Out:
#       artist               song  duration_ms  explicit  year  popularity  \
# 503  Rihanna      Pon de Replay       246960     False  2005          77
# 605  Rihanna                SOS       238920     False  2006          73
# 648  Rihanna         Unfaithful       226973     False  2006          70
# 701  Rihanna           Umbrella       275986     False  2008          81
# 726  Rihanna  Shut Up And Drive       212280     False  2008          69
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 503         0.779   0.640    7    -8.415     1       0.1590      0.000155
# 605         0.677   0.671    7    -4.905     1       0.0361      0.004000
# 648         0.588   0.391    0    -8.607     0       0.0334      0.839000
# 701         0.583   0.829    1    -4.603     1       0.1340      0.008640
# 726         0.735   0.826    1    -4.902     1       0.0349      0.001010
#
#      instrumentalness  liveness  valence    tempo              genre
# 503          0.000770    0.1010    0.498   99.019  hip hop, pop, R&B
# 605          0.000051    0.4130    0.527  137.046  hip hop, pop, R&B
# 648          0.000000    0.2270    0.349  144.069  hip hop, pop, R&B
# 701          0.000000    0.0426    0.575  174.028  hip hop, pop, R&B
# 726          0.129000    0.1970    0.740  132.964  hip hop, pop, R&B

# %%
#Посмотреть, в каких песнях Рианы самая продолжительная длина трека  
Rihanna.groupby('song', as_index=False).aggregate({'duration_ms':'max'}).sort_values('duration_ms', ascending=False)
# Out:
#                           song  duration_ms
# 17                    Umbrella       275986
# 3         Don't Stop The Music       267080
# 5                     Man Down       267000
# 20             What's My Name?       263173
# 4                         Hard       250600
# 8                Pon de Replay       246960
# 11                         S&M       243533
# 21         Where Have You Been       242680
# 14                        Stay       240706
# 12                         SOS       238920
# 2                    Disturbia       238626
# 7     Only Girl (In The World)       235493
# 15                  Take A Bow       229413
# 10            Russian Roulette       227533
# 18                  Unfaithful       226973
# 1                     Diamonds       225146
# 9                     Rude Boy       222920
# 22                        Work       219320
# 0   Bitch Better Have My Money       219305
# 19               We Found Love       215226
# 13           Shut Up And Drive       212280
# 16                      Te Amo       208426
# 6                    Needed Me       191600

# %%
#аналогичную группировку для popularity (какая песня самая популярная у Рианы)
Rihanna.groupby('song', as_index=False).aggregate({'popularity':'max'}).sort_values('popularity', ascending=False)
# Out:
#                           song  popularity
# 17                    Umbrella          81
# 6                    Needed Me          80
# 3         Don't Stop The Music          77
# 8                Pon de Replay          77
# 2                    Disturbia          76
# 14                        Stay          76
# 22                        Work          75
# 19               We Found Love          75
# 1                     Diamonds          75
# 15                  Take A Bow          74
# 9                     Rude Boy          74
# 12                         SOS          73
# 0   Bitch Better Have My Money          73
# 7     Only Girl (In The World)          73
# 11                         S&M          73
# 21         Where Have You Been          71
# 18                  Unfaithful          70
# 13           Shut Up And Drive          69
# 5                     Man Down          68
# 16                      Te Amo          67
# 20             What's My Name?          66
# 10            Russian Roulette          64
# 4                         Hard          55

# %%
#в каком году у Рианы песня самая популярная. Какая продолжительность этого трека (песни), какая танцевальность у этой песни?

# %%
#создадим новый  датафрейм с интерисующими нас колонками
popular_song = Rihanna[['song', 'popularity', 'year', 'duration_ms', 'danceability']]
popular_song
# Out:
#                             song  popularity  year  duration_ms  danceability
# 503                Pon de Replay          77  2005       246960         0.779
# 605                          SOS          73  2006       238920         0.677
# 648                   Unfaithful          70  2006       226973         0.588
# 701                     Umbrella          81  2008       275986         0.583
# 726            Shut Up And Drive          69  2008       212280         0.735
# 802                   Take A Bow          74  2008       229413         0.697
# 811                    Disturbia          76  2008       238626         0.707
# 819         Don't Stop The Music          77  2008       267080         0.835
# 935             Russian Roulette          64  2009       227533         0.480
# 1007    Only Girl (In The World)          73  2010       235493         0.789
# 1015                      Te Amo          67  2009       208426         0.567
# 1024                    Rude Boy          74  2009       222920         0.563
# 1042                        Hard          55  2009       250600         0.310
# 1052                    Man Down          68  2010       267000         0.470
# 1066             What's My Name?          66  2010       263173         0.692
# 1109                         S&M          73  2010       243533         0.767
# 1150               We Found Love          75  2011       215226         0.735
# 1158             What's My Name?          66  2010       263173         0.692
# 1200               We Found Love          75  2011       215226         0.735
# 1208         Where Have You Been          71  2011       242680         0.719
# 1230                    Diamonds          75  2012       225146         0.564
# 1396                        Stay          76  2012       240706         0.621
# 1539  Bitch Better Have My Money          73  2015       219305         0.781
# 1609                        Work          75  2016       219320         0.725
# 1636                   Needed Me          80  2016       191600         0.671

# %%
# какое значение популярности самое большое у песен Рианны
popular_song.popularity.max()
# Out:
# 81

# %%
#выведем строку из созданной ранее таблицы popular_song со значением popularity=81 и увидим данные самой популяной песни Рианны, год ее выпуска, продолжительностьтрека, танцевальность трека.
popular_song.query("popularity == 81")
# Out:
#          song  popularity  year  duration_ms  danceability
# 701  Umbrella          81  2008       275986         0.583

# %%
#как зависит уровень популярности песен Рианны касательно годов
Rihanna_year = Rihanna.groupby('year', as_index=False).aggregate({'popularity':'max'}).sort_values('popularity', ascending=False)
Rihanna_year
# Out:
#    year  popularity
# 2  2008          81
# 8  2016          80
# 0  2005          77
# 6  2012          76
# 5  2011          75
# 3  2009          74
# 1  2006          73
# 4  2010          73
# 7  2015          73

# %%
#как зависит уровень популярности песен Рианны от танцевальности
Rihanna_danceability = Rihanna.groupby('danceability', as_index=False).aggregate({'popularity':'max'}).sort_values('popularity', ascending=False)
Rihanna_danceability
# Out:
#     danceability  popularity
# 6          0.583          81
# 9          0.671          80
# 21         0.835          77
# 18         0.779          77
# 8          0.621          76
# 13         0.707          76
# 4          0.564          75
# 15         0.725          75
# 16         0.735          75
# 3          0.563          74
# 12         0.697          74
# 20         0.789          73
# 19         0.781          73
# 10         0.677          73
# 17         0.767          73
# 14         0.719          71
# 7          0.588          70
# 1          0.470          68
# 5          0.567          67
# 11         0.692          66
# 2          0.480          64
# 0          0.310          55

# %% [markdown]
# Проанализируем топ-5 самых популярных исполнителей (по частоте встречаемости)

# %%
# вывести топ-5 (по распространенности) исполнителей
df.artist.value_counts()
# Out:
# artist
# Rihanna           25
# Drake             23
# Eminem            21
# Calvin Harris     20
# Britney Spears    19
#                   ..
# Sidney Samson      1
# Cam’ron            1
# Elvis Presley      1
# Lucenzo            1
# Blanco Brown       1
# Name: count, Length: 835, dtype: int64

# %%
#Создать датафрейм Max_popular_aLLsong с данными только где artist= Rihanna, Drake, Eminem, Calvin Harris, Britney Spears
aLLsong = df.query("artist == 'Rihanna' or artist == 'Drake' or  artist == 'Eminem' or artist == 'Calvin Harris' or artist == 'Britney Spears'")
aLLsong.head(5)
# Out:
#              artist                    song  duration_ms  explicit  year  \
# 0    Britney Spears  Oops!...I Did It Again       211160     False  2000
# 6            Eminem     The Real Slim Shady       284200      True  2000
# 34   Britney Spears  Born to Make You Happy       243533     False  1999
# 98   Britney Spears                   Lucky       206226     False  2000
# 102          Eminem                    Stan       404106      True  2000
#
#      popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0            77         0.751   0.834    1    -5.444     0       0.0437
# 6            86         0.949   0.661    5    -4.244     0       0.0572
# 34           58         0.633   0.922   11    -4.842     0       0.0454
# 98           65         0.765   0.791    8    -5.707     1       0.0317
# 102          83         0.780   0.768    6    -4.325     0       0.2380
#
#      acousticness  instrumentalness  liveness  valence    tempo    genre
# 0          0.3000          0.000018    0.3550    0.894   95.053      pop
# 6          0.0302          0.000000    0.0454    0.760  104.504  hip hop
# 34         0.1160          0.000465    0.0710    0.686   84.110      pop
# 98         0.2620          0.000154    0.0669    0.966   95.026      pop
# 102        0.0371          0.000002    0.5180    0.507   80.063  hip hop

# %%
#среди топ 5 самых распостраненных исполнителей выбрать самое большое значение популярности их песни
top5_popular = aLLsong \
        .groupby(['artist'], as_index=False) \
        .aggregate({'popularity': 'max'}) \
        .query("artist == 'Rihanna' or artist == 'Drake' or  artist == 'Eminem' or artist == 'Calvin Harris' or artist == 'Britney Spears'") \
        .sort_values('popularity', ascending=False) 
top5_popular
# Out:
#            artist  popularity
# 3          Eminem          87
# 2           Drake          84
# 0  Britney Spears          81
# 1   Calvin Harris          81
# 4         Rihanna          81

# %%
#вывести все известные данные о самой известной песне топ-5 исполнителей
Max_popular_Eminem = aLLsong \
        .query("popularity == 87") \
        .query ("artist == 'Eminem'")
Max_popular_Drake = aLLsong \
        .query("popularity == 84") \
        .query ("artist == 'Drake'")
Max_popular_Britney_Spears = aLLsong \
        .query("popularity == 81") \
        .query ("artist == 'Britney Spears'")
Max_popular_Calvin_Harris = aLLsong \
        .query("popularity == 81") \
        .query ("artist == 'Calvin Harris'")
Max_popular_Rihanna = aLLsong \
        .query("popularity == 81") \
        .query ("artist == 'Rihanna'")

# %%
Max_popular_Eminem
# Out:
#      artist        song  duration_ms  explicit  year  popularity  \
# 201  Eminem  Without Me       290320      True  2002          87
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 201         0.908   0.669    7    -2.827     1       0.0738       0.00286
#
#      instrumentalness  liveness  valence    tempo    genre
# 201               0.0     0.237    0.662  112.238  hip hop

# %%
Max_popular_Drake
# Out:
#      artist       song  duration_ms  explicit  year  popularity  danceability  \
# 1601  Drake  One Dance       173986     False  2016          84         0.792
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 1601   0.625    1    -5.609     1       0.0536       0.00776
#
#       instrumentalness  liveness  valence    tempo              genre
# 1601            0.0018     0.329     0.37  103.967  hip hop, pop, R&B

# %%
Max_popular_Britney_Spears
# Out:
#              artist   song  duration_ms  explicit  year  popularity  \
# 402  Britney Spears  Toxic       198800     False  2003          81
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 402         0.774   0.838    5    -3.914     0        0.114        0.0249
#
#      instrumentalness  liveness  valence   tempo genre
# 402             0.025     0.242    0.924  143.04   pop

# %%
Max_popular_Calvin_Harris
# Out:
#              artist                      song  duration_ms  explicit  year  \
# 1812  Calvin Harris  One Kiss (with Dua Lipa)       214846     False  2018
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 1812          81         0.791   0.862    9     -3.24     0         0.11
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 1812         0.037          0.000022    0.0814    0.592  123.994
#
#                                genre
# 1812  hip hop, pop, Dance/Electronic

# %%
Max_popular_Rihanna
# Out:
#       artist      song  duration_ms  explicit  year  popularity  danceability  \
# 701  Rihanna  Umbrella       275986     False  2008          81         0.583
#
#      energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 701   0.829    1    -4.603     1        0.134       0.00864               0.0
#
#      liveness  valence    tempo              genre
# 701    0.0426    0.575  174.028  hip hop, pop, R&B

# %%
#с помощью функция .iloc выберем строки со всеми столбцами самых популярных песнен топ-5 самых распостаненных исполнителей

# %%
top5_artists = df.iloc[[201,1601,402, 1812, 701]]
top5_artists
# Out:
#               artist                      song  duration_ms  explicit  year  \
# 201           Eminem                Without Me       290320      True  2002
# 1601           Drake                 One Dance       173986     False  2016
# 402   Britney Spears                     Toxic       198800     False  2003
# 1812   Calvin Harris  One Kiss (with Dua Lipa)       214846     False  2018
# 701          Rihanna                  Umbrella       275986     False  2008
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 201           87         0.908   0.669    7    -2.827     1       0.0738
# 1601          84         0.792   0.625    1    -5.609     1       0.0536
# 402           81         0.774   0.838    5    -3.914     0       0.1140
# 1812          81         0.791   0.862    9    -3.240     0       0.1100
# 701           81         0.583   0.829    1    -4.603     1       0.1340
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 201        0.00286          0.000000    0.2370    0.662  112.238
# 1601       0.00776          0.001800    0.3290    0.370  103.967
# 402        0.02490          0.025000    0.2420    0.924  143.040
# 1812       0.03700          0.000022    0.0814    0.592  123.994
# 701        0.00864          0.000000    0.0426    0.575  174.028
#
#                                genre
# 201                          hip hop
# 1601               hip hop, pop, R&B
# 402                              pop
# 1812  hip hop, pop, Dance/Electronic
# 701                hip hop, pop, R&B

# %%
РАЗДЕЛ 2 Исследовательский анализ данных
# Out:
#   Cell In[244], line 1
#     РАЗДЕЛ 2 Исследовательский анализ данных
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
 
import scipy.stats as ss
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.api import anova_lm
from statsmodels.stats.multicomp import (pairwise_tukeyhsd,
                                         MultiComparison)
 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Построение карреляционной матрицы

# %%
#выводим числовые столбцы и передаем их в новый датасет
Song = df[['duration_ms', 'popularity', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
Song
# Out:
#       duration_ms  popularity  duration_ms  danceability  energy  key  \
# 0          211160          77       211160         0.751   0.834    1
# 1          167066          79       167066         0.434   0.897    0
# 2          250546          66       250546         0.529   0.496    7
# 3          224493          78       224493         0.551   0.913    0
# 4          200560          65       200560         0.614   0.928    8
# ...           ...         ...          ...           ...     ...  ...
# 1995       181026          79       181026         0.842   0.734    1
# 1996       178426          78       178426         0.552   0.702    9
# 1997       200593          69       200593         0.847   0.678    9
# 1998       171029          75       171029         0.741   0.520    8
# 1999       215280          85       215280         0.695   0.762    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -5.444     0       0.0437        0.3000          0.000018    0.3550
# 1       -4.918     1       0.0488        0.0103          0.000000    0.6120
# 2       -9.007     1       0.0290        0.1730          0.000000    0.2510
# 3       -4.063     0       0.0466        0.0263          0.000013    0.3470
# 4       -4.806     0       0.0516        0.0408          0.001040    0.0845
# ...        ...   ...          ...           ...               ...       ...
# 1995    -5.065     0       0.0588        0.0427          0.000000    0.1060
# 1996    -5.707     1       0.1570        0.1170          0.000021    0.1050
# 1997    -8.635     1       0.1090        0.0669          0.000000    0.2740
# 1998    -7.513     1       0.0656        0.4500          0.000002    0.2220
# 1999    -3.497     1       0.0395        0.1920          0.002440    0.0863
#
#       valence    tempo
# 0       0.894   95.053
# 1       0.684  148.726
# 2       0.278  136.859
# 3       0.544  119.992
# 4       0.879  172.656
# ...       ...      ...
# 1995    0.952  137.958
# 1996    0.564  169.994
# 1997    0.811   97.984
# 1998    0.347  102.998
# 1999    0.553  120.042
#
# [2000 rows x 14 columns]

# %%
Song.dtypes
# Out:
# duration_ms           int64
# popularity            int64
# duration_ms           int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# dtype: object

# %%
#создаем корреляционную матрицу
Song.corr()
# Out:
#                   duration_ms  popularity  duration_ms  danceability  \
# duration_ms          1.000000    0.050617     1.000000     -0.060057
# popularity           0.050617    1.000000     0.050617     -0.003546
# duration_ms          1.000000    0.050617     1.000000     -0.060057
# danceability        -0.060057   -0.003546    -0.060057      1.000000
# energy              -0.078763   -0.014021    -0.078763     -0.104038
# key                 -0.002560    0.014823    -0.002560      0.032731
# loudness            -0.079912    0.030632    -0.079912     -0.033315
# mode                -0.003848   -0.021353    -0.003848     -0.067528
# speechiness          0.066998    0.021162     0.066998      0.145590
# acousticness         0.010923    0.024619     0.010923     -0.065429
# instrumentalness    -0.004208   -0.048059    -0.004208      0.023207
# liveness             0.024941   -0.009856     0.024941     -0.126413
# valence             -0.116870   -0.016142    -0.116870      0.403178
# tempo               -0.028603    0.014288    -0.028603     -0.173418
#
#                     energy       key  loudness      mode  speechiness  \
# duration_ms      -0.078763 -0.002560 -0.079912 -0.003848     0.066998
# popularity       -0.014021  0.014823  0.030632 -0.021353     0.021162
# duration_ms      -0.078763 -0.002560 -0.079912 -0.003848     0.066998
# danceability     -0.104038  0.032731 -0.033315 -0.067528     0.145590
# energy            1.000000 -0.003446  0.651016 -0.040651    -0.057018
# key              -0.003446  1.000000 -0.007474 -0.153182     0.007147
# loudness          0.651016 -0.007474  1.000000 -0.028133    -0.076388
# mode             -0.040651 -0.153182 -0.028133  1.000000    -0.000077
# speechiness      -0.057018  0.007147 -0.076388 -0.000077     1.000000
# acousticness     -0.445469  0.002365 -0.310039  0.005744     0.000394
# instrumentalness  0.037861 -0.008173 -0.104925 -0.038613    -0.062954
# liveness          0.156761 -0.033071  0.102159  0.025439     0.061172
# valence           0.334474  0.036977  0.232150 -0.074681     0.073605
# tempo             0.153719 -0.001431  0.080709  0.048434     0.057747
#
#                   acousticness  instrumentalness  liveness   valence     tempo
# duration_ms           0.010923         -0.004208  0.024941 -0.116870 -0.028603
# popularity            0.024619         -0.048059 -0.009856 -0.016142  0.014288
# duration_ms           0.010923         -0.004208  0.024941 -0.116870 -0.028603
# danceability         -0.065429          0.023207 -0.126413  0.403178 -0.173418
# energy               -0.445469          0.037861  0.156761  0.334474  0.153719
# key                   0.002365         -0.008173 -0.033071  0.036977 -0.001431
# loudness             -0.310039         -0.104925  0.102159  0.232150  0.080709
# mode                  0.005744         -0.038613  0.025439 -0.074681  0.048434
# speechiness           0.000394         -0.062954  0.061172  0.073605  0.057747
# acousticness          1.000000         -0.005214 -0.110043 -0.128128 -0.103660
# instrumentalness     -0.005214          1.000000 -0.034897 -0.015192  0.034608
# liveness             -0.110043         -0.034897  1.000000  0.019040  0.028636
# valence              -0.128128         -0.015192  0.019040  1.000000 -0.025076
# tempo                -0.103660          0.034608  0.028636 -0.025076  1.000000

# %%
#создаем ту же матрицу корреляции с коэффициентами, округленными до 3 знаков после запятой
Song.corr().round(3)
# Out:
#                   duration_ms  popularity  duration_ms  danceability  energy  \
# duration_ms             1.000       0.051        1.000        -0.060  -0.079
# popularity              0.051       1.000        0.051        -0.004  -0.014
# duration_ms             1.000       0.051        1.000        -0.060  -0.079
# danceability           -0.060      -0.004       -0.060         1.000  -0.104
# energy                 -0.079      -0.014       -0.079        -0.104   1.000
# key                    -0.003       0.015       -0.003         0.033  -0.003
# loudness               -0.080       0.031       -0.080        -0.033   0.651
# mode                   -0.004      -0.021       -0.004        -0.068  -0.041
# speechiness             0.067       0.021        0.067         0.146  -0.057
# acousticness            0.011       0.025        0.011        -0.065  -0.445
# instrumentalness       -0.004      -0.048       -0.004         0.023   0.038
# liveness                0.025      -0.010        0.025        -0.126   0.157
# valence                -0.117      -0.016       -0.117         0.403   0.334
# tempo                  -0.029       0.014       -0.029        -0.173   0.154
#
#                     key  loudness   mode  speechiness  acousticness  \
# duration_ms      -0.003    -0.080 -0.004        0.067         0.011
# popularity        0.015     0.031 -0.021        0.021         0.025
# duration_ms      -0.003    -0.080 -0.004        0.067         0.011
# danceability      0.033    -0.033 -0.068        0.146        -0.065
# energy           -0.003     0.651 -0.041       -0.057        -0.445
# key               1.000    -0.007 -0.153        0.007         0.002
# loudness         -0.007     1.000 -0.028       -0.076        -0.310
# mode             -0.153    -0.028  1.000       -0.000         0.006
# speechiness       0.007    -0.076 -0.000        1.000         0.000
# acousticness      0.002    -0.310  0.006        0.000         1.000
# instrumentalness -0.008    -0.105 -0.039       -0.063        -0.005
# liveness         -0.033     0.102  0.025        0.061        -0.110
# valence           0.037     0.232 -0.075        0.074        -0.128
# tempo            -0.001     0.081  0.048        0.058        -0.104
#
#                   instrumentalness  liveness  valence  tempo
# duration_ms                 -0.004     0.025   -0.117 -0.029
# popularity                  -0.048    -0.010   -0.016  0.014
# duration_ms                 -0.004     0.025   -0.117 -0.029
# danceability                 0.023    -0.126    0.403 -0.173
# energy                       0.038     0.157    0.334  0.154
# key                         -0.008    -0.033    0.037 -0.001
# loudness                    -0.105     0.102    0.232  0.081
# mode                        -0.039     0.025   -0.075  0.048
# speechiness                 -0.063     0.061    0.074  0.058
# acousticness                -0.005    -0.110   -0.128 -0.104
# instrumentalness             1.000    -0.035   -0.015  0.035
# liveness                    -0.035     1.000    0.019  0.029
# valence                     -0.015     0.019    1.000 -0.025
# tempo                        0.035     0.029   -0.025  1.000

# %%
#Визуализация матрицы
corr = Song.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:383, in Styler._repr_html_(self)
#     378 """
#     379 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     380 default if an object is returned at the end of a cell.
#     381 """
#     382 if get_option("styler.render.repr") == "html":
# --> 383     return self.to_html()
#     384 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1308, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1305     obj.set_caption(caption)
#    1307 # Build HTML string..
# -> 1308 html = obj._render_html(
#    1309     sparse_index=sparse_index,
#    1310     sparse_columns=sparse_columns,
#    1311     max_rows=max_rows,
#    1312     max_cols=max_columns,
#    1313     exclude_styles=exclude_styles,
#    1314     encoding=encoding or get_option("styler.render.encoding"),
#    1315     doctype_html=doctype_html,
#    1316     **kwargs,
#    1317 )
#    1319 return save_to_buffer(
#    1320     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1321 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:205, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     193 def _render_html(
#     194     self,
#     195     sparse_index: bool,
#    (...)
#     199     **kwargs,
#     200 ) -> str:
#     201     """
#     202     Renders the ``Styler`` including all applied styles to HTML.
#     203     Generates a dict with necessary kwargs passed to jinja2 template.
#     204     """
# --> 205     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     206     d.update(kwargs)
#     207     return self.template_html.render(
#     208         **d,
#     209         html_table_tpl=self.template_html_table,
#     210         html_style_tpl=self.template_html_style,
#     211     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:162, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     148 def _render(
#     149     self,
#     150     sparse_index: bool,
#    (...)
#     154     blank: str = "",
#     155 ):
#     156     """
#     157     Computes and applies styles and then generates the general render dicts.
#     158
#     159     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     160     stylers for use within `_translate_latex`
#     161     """
# --> 162     self._compute()
#     163     dxs = []
#     164     ctx_len = len(self.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:257, in StylerRenderer._compute(self)
#     255 r = self
#     256 for func, args, kwargs in self._todo:
# --> 257     r = func(self)(*args, **kwargs)
#     258 return r
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1693, in Styler._apply(self, func, axis, subset, **kwargs)
#    1689 if not all(result.columns.isin(data.columns)):
#    1690     raise ValueError(
#    1691         msg.format("columns", result.columns.shape, data.columns.shape)
#    1692     )
# -> 1693 self._update_ctx(result)
#    1694 return self
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1505, in Styler._update_ctx(self, attrs)
#    1492 """
#    1493 Update the state of the ``Styler`` for data cells.
#    1494
#    (...)
#    1502     matter.
#    1503 """
#    1504 if not self.index.is_unique or not self.columns.is_unique:
# -> 1505     raise KeyError(
#    1506         "`Styler.apply` and `.applymap` are not compatible "
#    1507         "with non-unique index or columns."
#    1508     )
#    1510 for cn in attrs.columns:
#    1511     j = self.columns.get_loc(cn)
#
# KeyError: '`Styler.apply` and `.applymap` are not compatible with non-unique index or columns.'

# %%
#Матрица с разными цветами
corr = Song.corr()
corr.style.background_gradient(cmap='RdYlGn')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:383, in Styler._repr_html_(self)
#     378 """
#     379 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     380 default if an object is returned at the end of a cell.
#     381 """
#     382 if get_option("styler.render.repr") == "html":
# --> 383     return self.to_html()
#     384 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1308, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1305     obj.set_caption(caption)
#    1307 # Build HTML string..
# -> 1308 html = obj._render_html(
#    1309     sparse_index=sparse_index,
#    1310     sparse_columns=sparse_columns,
#    1311     max_rows=max_rows,
#    1312     max_cols=max_columns,
#    1313     exclude_styles=exclude_styles,
#    1314     encoding=encoding or get_option("styler.render.encoding"),
#    1315     doctype_html=doctype_html,
#    1316     **kwargs,
#    1317 )
#    1319 return save_to_buffer(
#    1320     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1321 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:205, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     193 def _render_html(
#     194     self,
#     195     sparse_index: bool,
#    (...)
#     199     **kwargs,
#     200 ) -> str:
#     201     """
#     202     Renders the ``Styler`` including all applied styles to HTML.
#     203     Generates a dict with necessary kwargs passed to jinja2 template.
#     204     """
# --> 205     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     206     d.update(kwargs)
#     207     return self.template_html.render(
#     208         **d,
#     209         html_table_tpl=self.template_html_table,
#     210         html_style_tpl=self.template_html_style,
#     211     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:162, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     148 def _render(
#     149     self,
#     150     sparse_index: bool,
#    (...)
#     154     blank: str = "",
#     155 ):
#     156     """
#     157     Computes and applies styles and then generates the general render dicts.
#     158
#     159     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     160     stylers for use within `_translate_latex`
#     161     """
# --> 162     self._compute()
#     163     dxs = []
#     164     ctx_len = len(self.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:257, in StylerRenderer._compute(self)
#     255 r = self
#     256 for func, args, kwargs in self._todo:
# --> 257     r = func(self)(*args, **kwargs)
#     258 return r
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1693, in Styler._apply(self, func, axis, subset, **kwargs)
#    1689 if not all(result.columns.isin(data.columns)):
#    1690     raise ValueError(
#    1691         msg.format("columns", result.columns.shape, data.columns.shape)
#    1692     )
# -> 1693 self._update_ctx(result)
#    1694 return self
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1505, in Styler._update_ctx(self, attrs)
#    1492 """
#    1493 Update the state of the ``Styler`` for data cells.
#    1494
#    (...)
#    1502     matter.
#    1503 """
#    1504 if not self.index.is_unique or not self.columns.is_unique:
# -> 1505     raise KeyError(
#    1506         "`Styler.apply` and `.applymap` are not compatible "
#    1507         "with non-unique index or columns."
#    1508     )
#    1510 for cn in attrs.columns:
#    1511     j = self.columns.get_loc(cn)
#
# KeyError: '`Styler.apply` and `.applymap` are not compatible with non-unique index or columns.'

# %% [markdown]
# Все коэффициенты корреляции по диагонали таблицы равны 1, потому что каждая переменная совершенна и коррелирует сам с собой.
# Все остальные коэффициенты корреляции указывают на корреляцию между различными попарными комбинациями переменных.

# %% [markdown]
# Самая большая кореляция между популярносью и длинной трека (duration_ms) (0.051) , чем больше популярность, тем больше длина трека.
# И наоброт, корреляция между популярностью и инструментальностью составляет -0.048 , что указывает на слабую отрицательную корреляцию. Большее значение популярности, связано с меньшим значением инструментальности.

# %% [markdown]
# РАССЧЕТЫ ДЛЯ длинны трека (duration_ms):

# %%
y = Song.popularity

x = Song.duration_ms

# %%
import numpy as np
import scipy.stats as st
import pandas as pd

# %%
st.spearmanr(x, y)
# Out:
# SignificanceResult(statistic=array([[ 1.        ,  1.        , -0.03662446],
#        [ 1.        ,  1.        , -0.03662446],
#        [-0.03662446, -0.03662446,  1.        ]]), pvalue=array([[0.        , 0.        , 0.10154251],
#        [0.        , 0.        , 0.10154251],
#        [0.10154251, 0.10154251, 0.        ]]))

# %% [markdown]
# линейная регресия:

# %%
y = Song[['popularity']]

x = Song[['duration_ms']]

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant (x)

# %%
model = sm. OLS (y, x). fit ()

# %%
print(model. summary ())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             popularity   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     5.132
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):             0.0236
# Time:                        18:55:44   Log-Likelihood:                -8955.6
# No. Observations:                2000   AIC:                         1.792e+04
# Df Residuals:                    1998   BIC:                         1.793e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          53.5603      2.827     18.948      0.000      48.017      59.104
# duration_ms   1.38e-05   6.09e-06      2.266      0.024    1.86e-06    2.57e-05
# duration_ms  1.379e-05   6.09e-06      2.265      0.024    1.85e-06    2.57e-05
# ==============================================================================
# Omnibus:                      651.223   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1626.471
# Skew:                          -1.795   Prob(JB):                         0.00
# Kurtosis:                       5.576   Cond. No.                     6.44e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.2e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Из сводки модели мы видим, что подобранное уравнение регрессии:
#
# Популярность = 53.5603 + (2.759e-05) * х (duration_ms)
#
# Это означает, что увеличение длинны трека (duration_ms) связано со средним увеличение популярности на 2.759e-05. А значение отрезка 53.5603 говорит нам о средней ожидаемой популярности песни за ноль продолжительности трека.
#
# P>|t|: это значение p, связанное с коэффициентами модели. Поскольку p-значение для duration_ms (0,000) меньше 0,05 (0.025), мы можем сказать, что существует статистически значимая связь между длинной трека  и популярностью. R-квадрат (0.003): это число говорит нам о том, какую процентную вариацию в длинне трека можно объяснить значением популярности. Вцелом, чем больше значение R-квадрата регрессионной модели, тем лучше независимые переменные способны предсказать значение переменной отклика. В этом случае 0,3% вариации длинны трека можно объяснить значением популярности. F-статистика и p-значение: F-статистика (5.132) и соответствующее значение p (0.0236) говорят нам об общей значимости регрессионной модели, т. е. о том, полезны ли независимые переменные в модели для объяснения вариации в переменной ответа. Поскольку p-значение в этом примере меньше 0,05, наша модель является статистически значимой, и считается, что для длинны трека  полезно для объяснения вариаций популярности.

# %%
import pandas as pd
import numpy as np
 
import scipy.stats as ss
import statsmodels.formula.api as smf
from statsmodels.stats.api import anova_lm
from statsmodels.stats.multicomp import (pairwise_tukeyhsd,
                                         MultiComparison)
 
 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy import stats

# %%
import statsmodels.api as sm

# %% [markdown]
# Для наглядности выведем среднее значение, дисперсию, медиану и т.д. в разрезе каждого исполнителя

# %%
df.groupby('artist').agg({'popularity': ['mean', 'var', 'std', 'median']}).sort_values('artist')
# Out:
#             popularity
#                   mean         var        std median
# artist
# *NSYNC            55.0   83.333333   9.128709   55.0
# 112               60.0   18.000000   4.242641   60.0
# 2 Chainz          70.0    2.000000   1.414214   70.0
# 21 Savage         76.0    8.000000   2.828427   76.0
# 2Pac              62.5   60.500000   7.778175   62.5
# ...                ...         ...        ...    ...
# girl in red       82.0         NaN        NaN   82.0
# iann dior         70.5    4.500000   2.121320   70.5
# iio               54.0         NaN        NaN   54.0
# t.A.T.u.          39.0         NaN        NaN   39.0
# will.i.am         63.5  179.666667  13.403980   65.0
#
# [835 rows x 4 columns]

# %% [markdown]
# возьмем explicit

# %%
df.groupby('explicit').agg({'popularity': ['mean', 'var', 'std', 'median']}).sort_values('explicit')
# Out:
#          popularity
#                mean         var        std median
# explicit
# False     59.259489  465.217149  21.568893   65.0
# True      61.484574  426.086580  20.641865   67.0

# %% [markdown]
# Проверим на нормальность распределения и равенство дисперссий

# %%
df_Fal = df.query('explicit == "False"')
df_Tr = df.query('explicit == "True"')

# %%
print(ss.shapiro(df_Fal.popularity.sample(45, random_state=17))), print(ss.shapiro(df_Tr.popularity.sample(45, random_state=17)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[266], line 1
# ----> 1 print(ss.shapiro(df_Fal.popularity.sample(45, random_state=17))), print(ss.shapiro(df_Tr.popularity.sample(45, random_state=17)))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5858, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5855 if weights is not None:
#    5856     weights = sample.preprocess_weights(self, weights, axis)
# -> 5858 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5859 result = self.take(sampled_indices, axis=axis)
#    5861 if ignore_index:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\sample.py:151, in sample(obj_len, size, replace, weights, random_state)
#     148     else:
#     149         raise ValueError("Invalid weights: weights sum to zero")
# --> 151 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     152     np.intp, copy=False
#     153 )
#
# File mtrand.pyx:928, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %% [markdown]
# **Н0 (нулевая гипотеза) - explicit не влияет популярность. Значение p-value < 0.05, следовательно мы отклоняем нулевую гипотезу и принимаем альтернативную.**
#
# **Различие в средних по популярности между true и false статистически значимо. Среднее выше у True - 61, у false  - 59**

# %%
sns.boxplot(x="explicit", y="popularity", data=df, palette=["hotpink", "dodgerblue"]) # для наглядности результатов
plt.grid(True)

# %% [markdown]
# Графики

# %%
# Line Chart

# %%
df_plot = df.groupby('year').agg({'song': 'count'}).reset_index()

# %%
#Line Chart количество песен по годам
df_plot.plot(kind = 'line', x='year', y = 'song')
# Out:
# <Axes: xlabel='year'>

# %%
total_song = df.groupby('artist',as_index=False).count().sort_values(by='song',ascending=False)
total_song
# Out:
#              artist  song  duration_ms  explicit  year  popularity  \
# 628         Rihanna    25           25        25    25          25
# 219           Drake    23           23        23    23          23
# 239          Eminem    21           21        21    21          21
# 127   Calvin Harris    20           20        20    20          20
# 118  Britney Spears    19           19        19    19          19
# ..              ...   ...          ...       ...   ...         ...
# 406            Khia     1            1         1     1           1
# 403    Kevin Rudolf     1            1         1     1           1
# 402    Kevin Lyttle     1            1         1     1           1
# 401     Kevin Gates     1            1         1     1           1
# 417           Kungs     1            1         1     1           1
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 628            25      25   25        25    25           25            25
# 219            23      23   23        23    23           23            23
# 239            21      21   21        21    21           21            21
# 127            20      20   20        20    20           20            20
# 118            19      19   19        19    19           19            19
# ..            ...     ...  ...       ...   ...          ...           ...
# 406             1       1    1         1     1            1             1
# 403             1       1    1         1     1            1             1
# 402             1       1    1         1     1            1             1
# 401             1       1    1         1     1            1             1
# 417             1       1    1         1     1            1             1
#
#      instrumentalness  liveness  valence  tempo  genre
# 628                25        25       25     25     25
# 219                23        23       23     23     23
# 239                21        21       21     21     21
# 127                20        20       20     20     20
# 118                19        19       19     19     19
# ..                ...       ...      ...    ...    ...
# 406                 1         1        1      1      1
# 403                 1         1        1      1      1
# 402                 1         1        1      1      1
# 401                 1         1        1      1      1
# 417                 1         1        1      1      1
#
# [835 rows x 18 columns]

# %% [markdown]
# Pie Chart по показателю "откровенный"

# %%
df['explicit'].value_counts().plot(kind='pie',  title="Bar Chart by explicit")
# Out:
# <Axes: title={'center': 'Bar Chart by explicit'}, ylabel='count'>

# %%
sns.boxplot(x="explicit", y="popularity", data=df, palette=["hotpink", "dodgerblue"]) # для наглядности результатов
plt.grid(True)

# %%
px.box(df,x='explicit',y='popularity'

# %% [markdown]
# Histogram
# частота встечаемости песен в разрезе годов

# %%
df['year'].hist()
# Out:
# <Axes: >

# %%
#график подсчета тональности (key), в кот находятся треки
sns.countplot(x='key',data=df)
# Out:
# <Axes: xlabel='key', ylabel='count'>

# %%
Rihanna_year
# Out:
#    year  popularity
# 2  2008          81
# 8  2016          80
# 0  2005          77
# 6  2012          76
# 5  2011          75
# 3  2009          74
# 1  2006          73
# 4  2010          73
# 7  2015          73

# %%
#Многомерный анализ популярности песен Рианны по годам
sns.pairplot(Rihanna_year)

# %% [markdown]
# формула идеального трека для самой большой популярности

# %%
top5_artists
# Out:
#               artist                      song  duration_ms  explicit  year  \
# 201           Eminem                Without Me       290320      True  2002
# 1601           Drake                 One Dance       173986     False  2016
# 402   Britney Spears                     Toxic       198800     False  2003
# 1812   Calvin Harris  One Kiss (with Dua Lipa)       214846     False  2018
# 701          Rihanna                  Umbrella       275986     False  2008
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 201           87         0.908   0.669    7    -2.827     1       0.0738
# 1601          84         0.792   0.625    1    -5.609     1       0.0536
# 402           81         0.774   0.838    5    -3.914     0       0.1140
# 1812          81         0.791   0.862    9    -3.240     0       0.1100
# 701           81         0.583   0.829    1    -4.603     1       0.1340
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 201        0.00286          0.000000    0.2370    0.662  112.238
# 1601       0.00776          0.001800    0.3290    0.370  103.967
# 402        0.02490          0.025000    0.2420    0.924  143.040
# 1812       0.03700          0.000022    0.0814    0.592  123.994
# 701        0.00864          0.000000    0.0426    0.575  174.028
#
#                                genre
# 201                          hip hop
# 1601               hip hop, pop, R&B
# 402                              pop
# 1812  hip hop, pop, Dance/Electronic
# 701                hip hop, pop, R&B

# %%
df['popularity'].value_counts()
# Out:
# popularity
# 0     126
# 69     76
# 68     75
# 73     69
# 74     69
#      ...
# 88      1
# 89      1
# 87      1
# 8       1
# 7       1
# Name: count, Length: 76, dtype: int64
